# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# cd /work
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     # Deepnote's notebook 6.5.5 used to require pyzmq<25.0.0,
#     # but this seems to no longer be the case.
#     # Here we install nbconvert manually, see https://github.com/RussTedrake/manipulation/issues/481
#     pip install -r ./requirements.txt nbconvert
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
#
# # Remove the global installation(s) of manipulation, to make sure
# # Deepnote's venv uses the local, most recent copy installed by the code above.
# # See https://github.com/RussTedrake/manipulation/issues/563
# rm -rf /usr/local/lib/python3.12/dist-packages/manipulation*
# Out:
# bash: line 2: cd: /work: No such file or directory
# sed: 1: "./requirements.txt": invalid command code .
# Looking in indexes: https://pypi.org/simple, https://drake-packages.csail.mit.edu/whl/nightly
# Requirement already satisfied: nbconvert in /opt/anaconda3/lib/python3.13/site-packages (7.16.6)
# Requirement already satisfied: manipulation==2025.10.20 in /opt/anaconda3/lib/python3.13/site-packages (from -r ./requirements.txt (line 3)) (2025.10.20)
# Requirement already satisfied: drake>=1.41.0 in /opt/anaconda3/lib/python3.13/site-packages (from manipulation==2025.10.20->-r ./requirements.txt (line 3)) (1.45.0)
# Requirement already satisfied: ipython>=7.8.0 in /opt/anaconda3/lib/python3.13/site-packages (from manipulation==2025.10.20->-r ./requirements.txt (line 3)) (8.30.0)
# Requirement already satisfied: lxml>=4.9.2 in /opt/anaconda3/lib/python3.13/site-packages (from lxml[html-clean]>=4.9.2->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (5.3.0)
# Requirement already satisfied: matplotlib>=3.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from manipulation==2025.10.20->-r ./requirements.txt (line 3)) (3.10.0)
# Requirement already satisfied: mpld3>=0.5.6 in /opt/anaconda3/lib/python3.13/site-packages (from manipulation==2025.10.20->-r ./requirements.txt (line 3)) (0.5.11)
# Requirement already satisfied: numpy<3.0.0,>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from manipulation==2025.10.20->-r ./requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: pyvirtualdisplay>=3.0 in /opt/anaconda3/lib/python3.13/site-packages (from manipulation==2025.10.20->-r ./requirements.txt (line 3)) (3.0)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.13/site-packages (from nbconvert) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert) (6.2.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/lib/python3.13/site-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /opt/anaconda3/lib/python3.13/site-packages (from nbconvert) (3.1.6)
# Requirement already satisfied: jupyter-core>=4.7 in /opt/anaconda3/lib/python3.13/site-packages (from nbconvert) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/lib/python3.13/site-packages (from nbconvert) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from nbconvert) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/lib/python3.13/site-packages (from nbconvert) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from nbconvert) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /opt/anaconda3/lib/python3.13/site-packages (from nbconvert) (5.10.4)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from nbconvert) (24.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/lib/python3.13/site-packages (from nbconvert) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /opt/anaconda3/lib/python3.13/site-packages (from nbconvert) (2.19.1)
# Requirement already satisfied: traitlets>=5.1 in /opt/anaconda3/lib/python3.13/site-packages (from nbconvert) (5.14.3)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.13/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert) (1.4.0)
# Requirement already satisfied: Mosek==11.0.24 in /opt/anaconda3/lib/python3.13/site-packages (from drake>=1.41.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (11.0.24)
# Requirement already satisfied: pydot in /opt/anaconda3/lib/python3.13/site-packages (from drake>=1.41.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (4.0.1)
# Requirement already satisfied: PyYAML in /opt/anaconda3/lib/python3.13/site-packages (from drake>=1.41.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (6.0.2)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=7.8.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=7.8.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=7.8.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=7.8.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (3.0.43)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=7.8.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=7.8.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (4.8.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.13/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.8.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/lib/python3.13/site-packages (from jedi>=0.16->ipython>=7.8.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from jupyter-core>=4.7->nbconvert) (4.3.7)
# Requirement already satisfied: lxml-html-clean in /opt/anaconda3/lib/python3.13/site-packages (from lxml[html-clean]>=4.9.2->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (0.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.7.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.7.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.7.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.7.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (1.4.8)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.7.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.7.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.7.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/anaconda3/lib/python3.13/site-packages (from nbclient>=0.5.0->nbconvert) (8.6.3)
# Requirement already satisfied: pyzmq>=23.0 in /opt/anaconda3/lib/python3.13/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (26.2.0)
# Requirement already satisfied: tornado>=6.2 in /opt/anaconda3/lib/python3.13/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (6.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/lib/python3.13/site-packages (from nbformat>=5.7->nbconvert) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /opt/anaconda3/lib/python3.13/site-packages (from nbformat>=5.7->nbconvert) (4.23.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.22.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.13/site-packages (from pexpect>4.3->ipython>=7.8.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.13/site-packages (from beautifulsoup4->nbconvert) (2.5)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython>=7.8.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython>=7.8.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython>=7.8.0->manipulation==2025.10.20->-r ./requirements.txt (line 3)) (0.2.2)
