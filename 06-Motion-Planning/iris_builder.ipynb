# %% [markdown]
# # The IRIS Builder for approximate convex decompositions of configuration space
#
# [IRIS in Configuration Space](https://drake.mit.edu/doxygen_cxx/group__geometry__optimization.html#ga3a51e0fec449a0abcf498f78a2a390a8) is a surprisingly effective and very useful tools for decomposing the (collision-free) configuration space into convex sets. IRIS itself only creates one convex region, but this notebook provides a number of algorithms and tools for calling IRIS in Configuration Space repeatedly to achieve an approximate convex cover of the space.
#
# The current version of the notebook uses the [IRIS-NP](https://arxiv.org/abs/2303.14737) algorithm -- which uses random samples to seed nonlinear optimization to find counter-examples. The certification of non-collision is only probabilistic -- the more samples you take, the more likely you are to have found all possible collisions. For rigorous certification of non-collision, we have [C-IRIS](https://arxiv.org/abs/2302.12219), which uses sums-of-squares optimization to guarantee non-collision. The final public implementation of that algorithm is under active development -- we will add it to the notebook soon!
#
# ## How to use this notebook
#
# <center><iframe width="560" height="315" src="https://www.youtube.com/embed/vaFlIxtiz4M" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe></center>
#
# The first few cells are used to set up your robot/environment and your IRIS configuration options. The rest of the cells are optional... you might run some of them multiple times, and might not use all of them. They are provided as a suite of tools for you to work with.

# %%
import multiprocessing as mp
import os.path
import time
from collections import OrderedDict
from typing import Dict

import numpy as np
import pydot
from IPython.display import SVG, display
from pydrake.common.value import AbstractValue
from pydrake.geometry import (
    Meshcat,
    MeshcatVisualizer,
    QueryObject,
    Rgba,
    Role,
    SceneGraph,
    Sphere,
    StartMeshcat,
)
from pydrake.geometry.optimization import (
    HPolyhedron,
    IrisInConfigurationSpace,
    IrisOptions,
    LoadIrisRegionsYamlFile,
    SaveIrisRegionsYamlFile,
)
from pydrake.math import RigidTransform, RollPitchYaw, RotationMatrix
from pydrake.multibody.inverse_kinematics import InverseKinematics
from pydrake.multibody.meshcat import JointSliders
from pydrake.multibody.parsing import PackageMap, Parser
from pydrake.multibody.plant import AddMultibodyPlantSceneGraph, MultibodyPlant
from pydrake.multibody.tree import Body
from pydrake.solvers import MathematicalProgram, Solve
from pydrake.systems.framework import DiagramBuilder, LeafSystem
from pydrake.visualization import AddDefaultVisualization, ModelVisualizer

from manipulation import running_as_notebook
from manipulation.utils import FindDataResource

# %%
# Start the visualizer (only run this once).
meshcat = StartMeshcat()
# Out:
# INFO:drake:Meshcat listening for connections at http://localhost:7007

# %% [markdown]
# # Setup

# %%
# iris_filename = "my_iris.yaml"
iris_filename = FindDataResource("iiwa_shelve_and_bins_science_robotics.yaml")
iris_regions = dict()
q = []

# %% [markdown]
# ## Configure IRIS
#
# You can find the documentation for IrisOptions [here](https://drake.mit.edu/doxygen_cxx/structdrake_1_1geometry_1_1optimization_1_1_iris_options.html).

# %%
iris_options = IrisOptions()
iris_options.iteration_limit = 10
# increase num_collision_infeasible_samples to improve the (probabilistic)
# certificate of having no collisions.
iris_options.num_collision_infeasible_samples = 3
iris_options.require_sample_point_is_contained = True
iris_options.relative_termination_threshold = 0.01
iris_options.termination_threshold = -1

# Additional options for this notebook:

# If use_existing_regions_as_obstacles is True, then iris_regions will be
# shrunk by regions_as_obstacles_margin, and then passed to
# iris_options.configuration_obstacles.
use_existing_regions_as_obstacles = True
regions_as_obstacles_scale_factor = 0.95

# We can compute some regions in parallel.
num_parallel = mp.cpu_count()

# %% [markdown]
# ## Some helper/worker methods

# %%
def ScaleHPolyhedron(hpoly, scale_factor):
    # Shift to the center.
    xc = hpoly.ChebyshevCenter()
    A = hpoly.A()
    b = hpoly.b() - A @ xc
    # Scale
    b = scale_factor * b
    # Shift back
    b = b + A @ xc
    return HPolyhedron(A, b)


def _CheckNonEmpty(region):
    prog = MathematicalProgram()
    x = prog.NewContinuousVariables(region.ambient_dimension())
    region.AddPointInSetConstraints(prog, x)
    result = Solve(prog)
    assert result.is_success()


def _CalcRegion(name, seed):
    builder = DiagramBuilder()
    plant = AddMultibodyPlantSceneGraph(builder, 0.0)[0]
    LoadRobot(plant)
    plant.Finalize()
    diagram = builder.Build()
    diagram_context = diagram.CreateDefaultContext()
    plant_context = plant.GetMyContextFromRoot(diagram_context)
    plant.SetPositions(plant_context, seed)
    if use_existing_regions_as_obstacles:
        iris_options.configuration_obstacles = [
            ScaleHPolyhedron(r, regions_as_obstacles_scale_factor)
            for k, r in iris_regions.items()
            if k != name
        ]
        for h in iris_options.configuration_obstacles:
            _CheckNonEmpty(h)
    else:
        iris_options.configuration_obstacles = None
    display(f"Computing region for seed: {name}")
    start_time = time.time()
    hpoly = IrisInConfigurationSpace(plant, plant_context, iris_options)
    display(
        f"Finished seed {name}; Computation time: {(time.time() - start_time):.2f} seconds"
    )

    _CheckNonEmpty(hpoly)
    reduced = hpoly.ReduceInequalities()
    _CheckNonEmpty(reduced)

    return reduced


def GenerateRegion(name, seed):
    global iris_regions
    iris_regions[name] = _CalcRegion(name, seed)
    SaveIrisRegionsYamlFile(f"{iris_filename}.autosave", iris_regions)


def GenerateRegions(seed_dict, verbose=True):
    if use_existing_regions_as_obstacles:
        # Then run serially
        for k, v in seed_dict.items():
            GenerateRegion(k, v)
        return

    loop_time = time.time()
    with mp.Pool(processes=num_parallel) as pool:
        new_regions = pool.starmap(_CalcRegion, [[k, v] for k, v in seed_dict.items()])

    if verbose:
        print("Loop time:", time.time() - loop_time)

    global iris_regions
    iris_regions.update(dict(list(zip(seed_dict.keys(), new_regions))))


def DrawRobot(query_object: QueryObject, meshcat_prefix: str, draw_world: bool = True):
    rgba = Rgba(0.7, 0.7, 0.7, 0.3)
    role = Role.kProximity
    # This is a minimal replication of the work done in MeshcatVisualizer.
    inspector = query_object.inspector()
    for frame_id in inspector.GetAllFrameIds():
        if frame_id == inspector.world_frame_id():
            if not draw_world:
                continue
            frame_path = meshcat_prefix
        else:
            frame_path = f"{meshcat_prefix}/{inspector.GetName(frame_id)}"
        frame_path.replace("::", "/")
        frame_has_any_geometry = False
        for geom_id in inspector.GetGeometries(frame_id, role):
            path = f"{frame_path}/{geom_id.get_value()}"
            path.replace("::", "/")
            meshcat.SetObject(path, inspector.GetShape(geom_id), rgba)
            meshcat.SetTransform(path, inspector.GetPoseInFrame(geom_id))
            frame_has_any_geometry = True

        if frame_has_any_geometry:
            X_WF = query_object.GetPoseInWorld(frame_id)
            meshcat.SetTransform(frame_path, X_WF)


def VisualizeRegion(region_name, num_to_draw=30, draw_illustration_role_once=True):
    """
    A simple hit-and-run-style idea for visualizing the IRIS regions:
    1. Start at the center. Pick a random direction and run to the boundary.
    2. Pick a new random direction; project it onto the current boundary, and run along it. Repeat
    """

    builder = DiagramBuilder()
    plant, scene_graph = AddMultibodyPlantSceneGraph(builder, time_step=0.0)
    LoadRobot(plant)
    plant.Finalize()
    if draw_illustration_role_once:
        MeshcatVisualizer.AddToBuilder(builder, scene_graph, meshcat)
    diagram = builder.Build()
    context = diagram.CreateDefaultContext()
    plant_context = plant.GetMyMutableContextFromRoot(context)
    scene_graph_context = scene_graph.GetMyContextFromRoot(context)

    global iris_regions
    region = iris_regions[region_name]

    q = region.ChebyshevCenter()
    plant.SetPositions(plant_context, q)
    diagram.ForcedPublish(context)

    query = scene_graph.get_query_output_port().Eval(scene_graph_context)
    DrawRobot(query, f"{region_name}/0", True)

    rng = np.random.default_rng()
    nq = plant.num_positions()
    prog = MathematicalProgram()
    qvar = prog.NewContinuousVariables(nq, "q")
    prog.AddLinearConstraint(region.A(), 0 * region.b() - np.inf, region.b(), qvar)
    cost = prog.AddLinearCost(np.ones((nq, 1)), qvar)

    for i in range(1, num_to_draw):
        direction = rng.standard_normal(nq)
        cost.evaluator().UpdateCoefficients(direction)

        result = Solve(prog)
        assert result.is_success()

        q = result.GetSolution(qvar)
        plant.SetPositions(plant_context, q)
        query = scene_graph.get_query_output_port().Eval(scene_graph_context)
        DrawRobot(query, f"{region_name}/{i}", False)


def VisualizeRegions():
    for k in iris_regions.keys():
        meshcat.Delete()
        VisualizeRegion(k)
        button_name = f"Visualizing {k}; Press for next region"
        meshcat.AddButton(button_name, "Enter")
        print("Press Enter to visualize the next region")
        while meshcat.GetButtonClicks(button_name) < 1:
            time.sleep(1.0)
        meshcat.DeleteButton(button_name)


# TODO(russt): See https://github.com/RobotLocomotion/drake/pull/19520
class PoseSelector(LeafSystem):
    def __init__(
        self,
        body_index=None,
    ):
        LeafSystem.__init__(self)
        self._body_index = body_index
        self.DeclareAbstractInputPort(
            "body_poses", AbstractValue.Make([RigidTransform()])
        )
        self.DeclareAbstractOutputPort(
            "pose",
            lambda: AbstractValue.Make(RigidTransform()),
            self.CalcOutput,
        )

    def CalcOutput(self, context, output):
        body_poses = self.get_input_port().Eval(context)
        output.set_value(body_poses[self._body_index])

# %% [markdown]
# ## Define your robot/environment
#
# You should edit the `LoadRobot` method in this cell to set up your robot/environment. See the [Authoring Multibody Simulation](authoring_multibody_simulation.ipynb) tutorial for more background about the supported input formats.

# %%
def LoadRobot(plant: MultibodyPlant) -> Body:
    """Setup your plant, and return the body corresponding to your
    end-effector."""
    parser = Parser(plant)

    # We'll use some tables, shelves, and bins from a remote resource.
    parser.package_map().AddRemote(
        package_name="gcs",
        params=PackageMap.RemoteParams(
            urls=[
                f"https://github.com/mpetersen94/gcs/archive/refs/tags/arxiv_paper_version.tar.gz"
            ],
            sha256=("6dd5e841c8228561b6d622f592359c36517cd3c3d5e1d3e04df74b2f5435680c"),
            strip_prefix="gcs-arxiv_paper_version",
        ),
    )

    model_directives = """    
directives:

# Add iiwa
- add_model:
    name: iiwa
    file: package://drake_models/iiwa_description/urdf/iiwa14_primitive_collision.urdf
    default_joint_positions:
        iiwa_joint_1: [0]
        iiwa_joint_2: [0.3]
        iiwa_joint_3: [0]
        iiwa_joint_4: [-1.8]
        iiwa_joint_5: [0]
        iiwa_joint_6: [1]
        iiwa_joint_7: [1.57]

- add_weld:
    parent: world
    child: iiwa::base

# Add schunk
- add_model:
    name: wsg
    file: package://drake_models/wsg_50_description/sdf/schunk_wsg_50_welded_fingers.sdf

- add_weld:
    parent: iiwa::iiwa_link_7
    child: wsg::body
    X_PC:
      translation: [0, 0, 0.114]
      rotation: !Rpy { deg: [90.0, 0.0, 0.0 ]}

# Add shelves
- add_model:
    name: shelves
    file: package://gcs/models/shelves/shelves.sdf

- add_weld:
    parent: world
    child: shelves::shelves_body
    X_PC:
      translation: [0.85, 0, 0.4]

# Add Bins
- add_model:
    name: binR
    file: package://gcs/models/bin/bin.sdf

- add_weld:
    parent: world
    child: binR::bin_base
    X_PC:
      translation: [0, -0.6, 0]
      rotation: !Rpy { deg: [0.0, 0.0, 90.0 ]}

- add_model:
    name: binL
    file: package://gcs/models/bin/bin.sdf

- add_weld:
    parent: world
    child: binL::bin_base
    X_PC:
      translation: [0, 0.6, 0]
      rotation: !Rpy { deg: [0.0, 0.0, 90.0 ]}

# Add table
- add_model:
    name: table
    file: package://gcs/models/table/table_wide.sdf

- add_weld:
    parent: world
    child: table::table_body
    X_PC:
      translation: [0.4, 0.0, 0.0]
      rotation: !Rpy { deg: [0., 0., 00]}
"""

    parser.AddModelsFromString(model_directives, ".dmd.yaml")
    gripper = plant.GetModelInstanceByName("wsg")
    end_effector_body = plant.GetBodyByName("body", gripper)
    return end_effector_body


# Sometimes it's useful to use inverse kinematics to find the seeds. You might
# need to adapt this to your robot. This helper takes an end-effector frame, E,
# and a desired pose for that frame in the world coordinates, X_WE.
def MyInverseKinematics(X_WE, plant=None, context=None):
    if not plant:
        plant = MultibodyPlant(0.0)
        LoadRobot(plant)
        plant.Finalize()
    if not context:
        context = plant.CreateDefaultContext()
    # E = ee_body.body_frame()
    E = plant.GetBodyByName("body").body_frame()

    ik = InverseKinematics(plant, context)

    ik.AddPositionConstraint(
        E, [0, 0, 0], plant.world_frame(), X_WE.translation(), X_WE.translation()
    )

    ik.AddOrientationConstraint(
        E, RotationMatrix(), plant.world_frame(), X_WE.rotation(), 0.001
    )

    prog = ik.get_mutable_prog()
    q = ik.q()

    q0 = plant.GetPositions(context)
    prog.AddQuadraticErrorCost(np.identity(len(q)), q0, q)
    prog.SetInitialGuess(q, q0)
    result = Solve(ik.prog())
    if not result.is_success():
        print("IK failed")
        return None
    plant.SetPositions(context, result.GetSolution(q))
    return result.GetSolution(q)

# %%
# This is a handy way to test your model.
v = ModelVisualizer(meshcat=meshcat)
LoadRobot(v.parser().plant());
# v.Run()

# %% [markdown]
# ## Load any previously computed regions
#
# TODO(russt): Should we somehow validate that these are still valid for the robot/environment?

# %%
if os.path.isfile(iris_filename):
    iris_regions.update(LoadIrisRegionsYamlFile(iris_filename))
    print(f"Loaded iris regions from {iris_filename}.")
else:
    print(f"{iris_filename} not found. No previously computed regions were loaded.")
# Out:
# Loaded iris regions from /opt/anaconda3/lib/python3.13/site-packages/book/data/iiwa_shelve_and_bins_science_robotics.yaml.

# %% [markdown]
# # Make new IRIS regions

# %% [markdown]
# ## Consider your collision geometry
#
# Computing configuration space regions is a challenging computational problem! The runtime will scale with the number of collision candidate pairs.  This cell displays some information about the collision geometries.  Consider using [collision filters](https://drake.mit.edu/doxygen_cxx/classdrake_1_1geometry_1_1_collision_filter_manager.html) to reduce the complexity of the problem.  You can also add the filters in urdf/sdf using the [drake:collision_filter_group](https://drake.mit.edu/doxygen_cxx/group__multibody__parsing.html#tag_drake_collision_filter_group) tag.

# %%
def CollisionGeometryReport():
    builder = DiagramBuilder()
    plant, scene_graph = AddMultibodyPlantSceneGraph(builder, time_step=0.0)
    LoadRobot(plant)
    plant.Finalize()
    diagram = builder.Build()
    context = diagram.CreateDefaultContext()
    plant_context = plant.GetMyContextFromRoot(context)

    query_object = plant.get_geometry_query_input_port().Eval(plant_context)
    inspector = query_object.inspector()
    pairs = inspector.GetCollisionCandidates()
    for geomA, geomB in pairs:
        frameA = inspector.GetFrameId(geomA)
        frameB = inspector.GetFrameId(geomB)
        print(
            f"{inspector.GetName(geomA)} (in {inspector.GetName(frameA)}) + {inspector.GetName(geomB)} (in {inspector.GetName(frameB)})"
        )


CollisionGeometryReport()
# Out:
# iiwa::Cylinder (in iiwa::iiwa_link_5) + binL::left (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_0) + wsg::collision (in wsg::right_finger)
# wsg::collision (in wsg::right_finger) + binL::right (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_5) + table::table_top (in table::table_body)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + binR::right (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + wsg::collision (in wsg::body)
# iiwa::Cylinder (in iiwa::iiwa_link_5) + wsg::collision (in wsg::body)
# iiwa::Mesh (in iiwa::iiwa_link_7) + binL::bottom (in binL::bin_base)
# wsg::collision (in wsg::left_finger) + shelves::right_wall (in shelves::shelves_body)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + binL::back (in binL::bin_base)
# wsg::collision (in wsg::left_finger) + shelves::shelf_upper (in shelves::top_and_bottom)
# iiwa::Mesh (in iiwa::iiwa_link_6) + shelves::top (in shelves::top_and_bottom)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + shelves::left_wall (in shelves::shelves_body)
# iiwa::Mesh (in iiwa::iiwa_link_6) + binR::front (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + shelves::shelf_upper (in shelves::top_and_bottom)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + binR::left (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + binR::right (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + binL::front (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + binL::back (in binL::bin_base)
# wsg::collision (in wsg::body) + binR::back (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_5) + binL::right (in binL::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_6) + binL::bottom (in binL::bin_base)
# wsg::collision (in wsg::right_finger) + binL::bottom (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + iiwa::Mesh (in iiwa::iiwa_link_7)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + binR::bottom (in binR::bin_base)
# wsg::collision (in wsg::left_finger) + shelves::left_wall (in shelves::shelves_body)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + binL::left (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + wsg::collision (in wsg::right_finger)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + iiwa::Cylinder (in iiwa::iiwa_link_3)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + table::table_top (in table::table_body)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + shelves::top (in shelves::top_and_bottom)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + shelves::left_wall (in shelves::shelves_body)
# iiwa::Mesh (in iiwa::iiwa_link_6) + shelves::shelf_lower (in shelves::top_and_bottom)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + binR::front (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + binR::right (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + binR::bottom (in binR::bin_base)
# wsg::collision (in wsg::body) + shelves::shelf_upper (in shelves::top_and_bottom)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + binL::back (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + binL::left (in binL::bin_base)
# wsg::collision (in wsg::body) + binR::left (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_0) + wsg::collision (in wsg::left_finger)
# wsg::collision (in wsg::body) + binL::front (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_5) + binL::bottom (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + binL::right (in binL::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_6) + shelves::right_wall (in shelves::shelves_body)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + shelves::shelf_lower (in shelves::top_and_bottom)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + binR::back (in binR::bin_base)
# wsg::collision (in wsg::body) + shelves::left_wall (in shelves::shelves_body)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + binR::bottom (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + wsg::collision (in wsg::left_finger)
# iiwa::Mesh (in iiwa::iiwa_link_7) + shelves::top (in shelves::top_and_bottom)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + binL::left (in binL::bin_base)
# wsg::collision (in wsg::body) + binR::right (in binR::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_7) + binR::front (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + table::table_top (in table::table_body)
# wsg::collision (in wsg::body) + binL::back (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + wsg::collision (in wsg::left_finger)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + shelves::right_wall (in shelves::shelves_body)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + shelves::shelf_upper (in shelves::top_and_bottom)
# wsg::collision (in wsg::right_finger) + shelves::top (in shelves::top_and_bottom)
# wsg::collision (in wsg::left_finger) + binR::left (in binR::bin_base)
# wsg::collision (in wsg::right_finger) + binR::front (in binR::bin_base)
# wsg::collision (in wsg::left_finger) + binL::front (in binL::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_7) + shelves::shelf_lower (in shelves::top_and_bottom)
# iiwa::Cylinder (in iiwa::iiwa_link_0) + wsg::collision (in wsg::body)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + binL::right (in binL::bin_base)
# wsg::collision (in wsg::body) + binR::bottom (in binR::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_7) + binR::back (in binR::bin_base)
# wsg::collision (in wsg::body) + binL::left (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_0) + iiwa::Cylinder (in iiwa::iiwa_link_4)
# iiwa::Mesh (in iiwa::iiwa_link_6) + wsg::collision (in wsg::right_finger)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + wsg::collision (in wsg::left_finger)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + shelves::left_wall (in shelves::shelves_body)
# iiwa::Cylinder (in iiwa::iiwa_link_5) + shelves::top (in shelves::top_and_bottom)
# wsg::collision (in wsg::right_finger) + shelves::shelf_lower (in shelves::top_and_bottom)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + wsg::collision (in wsg::body)
# wsg::collision (in wsg::left_finger) + binR::right (in binR::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_7) + shelves::right_wall (in shelves::shelves_body)
# iiwa::Cylinder (in iiwa::iiwa_link_5) + binR::front (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_0) + iiwa::Mesh (in iiwa::iiwa_link_7)
# iiwa::Mesh (in iiwa::iiwa_link_6) + binR::back (in binR::bin_base)
# wsg::collision (in wsg::left_finger) + binL::back (in binL::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_7) + shelves::shelf_upper (in shelves::top_and_bottom)
# wsg::collision (in wsg::right_finger) + binR::back (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + iiwa::Cylinder (in iiwa::iiwa_link_4)
# wsg::collision (in wsg::body) + binL::right (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + table::table_top (in table::table_body)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + wsg::collision (in wsg::body)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + wsg::collision (in wsg::right_finger)
# wsg::collision (in wsg::right_finger) + shelves::right_wall (in shelves::shelves_body)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + iiwa::Mesh (in iiwa::iiwa_link_7)
# iiwa::Cylinder (in iiwa::iiwa_link_5) + shelves::shelf_lower (in shelves::top_and_bottom)
# iiwa::Cylinder (in iiwa::iiwa_link_0) + iiwa::Mesh (in iiwa::iiwa_link_6)
# iiwa::Mesh (in iiwa::iiwa_link_6) + shelves::shelf_upper (in shelves::top_and_bottom)
# wsg::collision (in wsg::left_finger) + binR::bottom (in binR::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_7) + shelves::left_wall (in shelves::shelves_body)
# iiwa::Cylinder (in iiwa::iiwa_link_5) + binR::back (in binR::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_6) + binR::left (in binR::bin_base)
# wsg::collision (in wsg::right_finger) + shelves::shelf_upper (in shelves::top_and_bottom)
# iiwa::Cylinder (in iiwa::iiwa_link_0) + iiwa::Cylinder (in iiwa::iiwa_link_2)
# wsg::collision (in wsg::left_finger) + binL::left (in binL::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_6) + binL::front (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + shelves::top (in shelves::top_and_bottom)
# wsg::collision (in wsg::left_finger) + table::table_top (in table::table_body)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + binR::front (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + binL::right (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + iiwa::Mesh (in iiwa::iiwa_link_7)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + wsg::collision (in wsg::body)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + iiwa::Mesh (in iiwa::iiwa_link_6)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + shelves::top (in shelves::top_and_bottom)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + iiwa::Cylinder (in iiwa::iiwa_link_4)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + binL::bottom (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_5) + shelves::right_wall (in shelves::shelves_body)
# iiwa::Mesh (in iiwa::iiwa_link_6) + shelves::left_wall (in shelves::shelves_body)
# wsg::collision (in wsg::right_finger) + shelves::left_wall (in shelves::shelves_body)
# iiwa::Cylinder (in iiwa::iiwa_link_5) + shelves::shelf_upper (in shelves::top_and_bottom)
# iiwa::Cylinder (in iiwa::iiwa_link_5) + binR::left (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + binR::left (in binR::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_6) + binR::right (in binR::bin_base)
# wsg::collision (in wsg::left_finger) + binL::right (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + binL::front (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + shelves::shelf_lower (in shelves::top_and_bottom)
# iiwa::Mesh (in iiwa::iiwa_link_6) + binL::back (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + iiwa::Mesh (in iiwa::iiwa_link_6)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + binL::bottom (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + iiwa::Mesh (in iiwa::iiwa_link_7)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + wsg::collision (in wsg::left_finger)
# wsg::collision (in wsg::body) + table::table_top (in table::table_body)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + shelves::top (in shelves::top_and_bottom)
# iiwa::Cylinder (in iiwa::iiwa_link_5) + shelves::left_wall (in shelves::shelves_body)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + binR::front (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + binR::right (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + shelves::right_wall (in shelves::shelves_body)
# iiwa::Mesh (in iiwa::iiwa_link_6) + binR::bottom (in binR::bin_base)
# wsg::collision (in wsg::left_finger) + binL::bottom (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + binL::back (in binL::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_6) + binL::left (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + iiwa::Mesh (in iiwa::iiwa_link_6)
# iiwa::Mesh (in iiwa::iiwa_link_6) + table::table_top (in table::table_body)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + binL::bottom (in binL::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_7) + binR::left (in binR::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_7) + binL::front (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + shelves::right_wall (in shelves::shelves_body)
# iiwa::Cylinder (in iiwa::iiwa_link_5) + wsg::collision (in wsg::right_finger)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + shelves::shelf_lower (in shelves::top_and_bottom)
# wsg::collision (in wsg::body) + shelves::top (in shelves::top_and_bottom)
# wsg::collision (in wsg::body) + binR::front (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + binR::bottom (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + binL::left (in binL::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_6) + binL::right (in binL::bin_base)
# wsg::collision (in wsg::right_finger) + binR::left (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + table::table_top (in table::table_body)
# wsg::collision (in wsg::right_finger) + binL::front (in binL::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_7) + binR::right (in binR::bin_base)
# wsg::collision (in wsg::body) + binL::bottom (in binL::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_7) + binL::back (in binL::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_6) + wsg::collision (in wsg::left_finger)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + shelves::right_wall (in shelves::shelves_body)
# iiwa::Cylinder (in iiwa::iiwa_link_0) + iiwa::Cylinder (in iiwa::iiwa_link_5)
# wsg::collision (in wsg::body) + shelves::shelf_lower (in shelves::top_and_bottom)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + wsg::collision (in wsg::right_finger)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + binR::front (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + binL::right (in binL::bin_base)
# wsg::collision (in wsg::right_finger) + binR::right (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_5) + binL::front (in binL::bin_base)
# wsg::collision (in wsg::right_finger) + binL::back (in binL::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_7) + binR::bottom (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + binR::back (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + iiwa::Cylinder (in iiwa::iiwa_link_5)
# iiwa::Mesh (in iiwa::iiwa_link_7) + binL::left (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_5) + wsg::collision (in wsg::left_finger)
# iiwa::Mesh (in iiwa::iiwa_link_7) + table::table_top (in table::table_body)
# wsg::collision (in wsg::left_finger) + shelves::top (in shelves::top_and_bottom)
# wsg::collision (in wsg::body) + shelves::right_wall (in shelves::shelves_body)
# wsg::collision (in wsg::left_finger) + binR::front (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + shelves::shelf_lower (in shelves::top_and_bottom)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + binR::back (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + iiwa::Cylinder (in iiwa::iiwa_link_5)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + iiwa::Mesh (in iiwa::iiwa_link_6)
# iiwa::Cylinder (in iiwa::iiwa_link_4) + binL::bottom (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_5) + binR::right (in binR::bin_base)
# wsg::collision (in wsg::right_finger) + binR::bottom (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_5) + binL::back (in binL::bin_base)
# wsg::collision (in wsg::right_finger) + binL::left (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + shelves::shelf_upper (in shelves::top_and_bottom)
# iiwa::Cylinder (in iiwa::iiwa_link_0) + iiwa::Cylinder (in iiwa::iiwa_link_3)
# wsg::collision (in wsg::right_finger) + table::table_top (in table::table_body)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + binR::left (in binR::bin_base)
# iiwa::Mesh (in iiwa::iiwa_link_6) + wsg::collision (in wsg::body)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + wsg::collision (in wsg::right_finger)
# iiwa::Mesh (in iiwa::iiwa_link_7) + binL::right (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + binL::front (in binL::bin_base)
# wsg::collision (in wsg::left_finger) + shelves::shelf_lower (in shelves::top_and_bottom)
# wsg::collision (in wsg::left_finger) + binR::back (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + shelves::shelf_upper (in shelves::top_and_bottom)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + binR::back (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + binR::left (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_1) + iiwa::Cylinder (in iiwa::iiwa_link_5)
# iiwa::Cylinder (in iiwa::iiwa_link_3) + binL::front (in binL::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_5) + binR::bottom (in binR::bin_base)
# iiwa::Cylinder (in iiwa::iiwa_link_2) + shelves::left_wall (in shelves::shelves_body)

# %% [markdown]
# ## Run IRIS on manually-specified seeds

# %%
def get_default_position():
    plant = MultibodyPlant(0.0)
    LoadRobot(plant)
    plant.Finalize()
    context = plant.CreateDefaultContext()
    return plant.GetPositions(context)


# Note: The order of the seeds matters when we are using existing regions as
# configuration_obstacles.
seeds = OrderedDict()
seeds["Home Position"] = get_default_position()
seeds["Above Shelve"] = MyInverseKinematics(
    RigidTransform(RollPitchYaw(0, -np.pi, -np.pi / 2), [0.75, 0, 0.9])
)
seeds["Top Rack"] = MyInverseKinematics(
    RigidTransform(RollPitchYaw(0, -np.pi, -np.pi / 2), [0.75, 0, 0.67])
)
seeds["Middle Rack"] = MyInverseKinematics(
    RigidTransform(RollPitchYaw(0, -np.pi, -np.pi / 2), [0.75, 0, 0.41])
)
seeds["Left Bin"] = MyInverseKinematics(
    RigidTransform(RollPitchYaw(np.pi / 2, np.pi, 0), [0.0, 0.6, 0.22])
)
seeds["Right Bin"] = MyInverseKinematics(
    RigidTransform(RollPitchYaw(np.pi / 2, np.pi, np.pi), [0.0, -0.6, 0.22])
)
seeds["Front to Shelve"] = np.array([0, 0.2, 0, -2.09, 0, -0.3, np.pi / 2])
seeds["Left to Shelve"] = np.array([0.8, 0.7, 0, -1.6, 0, 0, np.pi / 2])
seeds["Right to Shelve"] = np.array([-0.8, 0.7, 0, -1.6, 0, 0, np.pi / 2])

# %%
# v = ModelVisualizer(meshcat=meshcat)
# LoadRobot(v.parser().plant())
# v.Run(position=seeds["Top Rack"], loop_once=True)

# %%
# You generate one region at a time, e.g.
# GenerateRegion("Top Rack", seeds["Top Rack"])

# Or (re-)generate all of the regions
# This will run in parallel iff use_existing_regions_as_obstacles is False
if running_as_notebook:
    iris_regions = dict()  # reset the iris regions
    GenerateRegions(seeds)
# Out:
# 'Computing region for seed: Home Position'
# /var/folders/k4/mg5n76b53w31r9_hw85j51xh0000gn/T/ipykernel_24194/1304875030.py:42: DrakeDeprecationWarning: (Deprecated.)
#
# Deprecated:
#     Use IrisNp instead. This will be removed from Drake on or after
#     2025-12-01.
#   hpoly = IrisInConfigurationSpace(plant, plant_context, iris_options)
# INFO:drake:IrisNp iteration 0
# INFO:drake:IrisNp iteration 1
# INFO:drake:IrisNp iteration 2
# INFO:drake: Checking wsg::collision against shelves::shelf_lower has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking wsg::collision against shelves::shelf_lower after 35 counter-example searches.
# INFO:drake: Checking wsg::collision against table::table_top has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking wsg::collision against table::table_top after 38 counter-example searches.
# INFO:drake:IrisNp iteration 3
# INFO:drake: Checking iiwa::Mesh against shelves::shelf_upper has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking iiwa::Mesh against shelves::shelf_upper after 32 counter-example searches.
# INFO:drake:IrisNp iteration 4
# INFO:drake:IrisNp iteration 5
# INFO:drake:IrisNp iteration 6
# INFO:drake: Checking wsg::collision against table::table_top has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking wsg::collision against table::table_top after 31 counter-example searches.
# INFO:drake: Checking wsg::collision against table::table_top has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking wsg::collision against table::table_top after 30 counter-example searches.
# INFO:drake: Checking iiwa::Mesh against shelves::top has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking iiwa::Mesh against shelves::top after 33 counter-example searches.
# INFO:drake:IrisNp: terminating iterations because the seed point is no longer in the region.
# 'Finished seed Home Position; Computation time: 94.68 seconds'
# 'Computing region for seed: Above Shelve'
# INFO:drake:IrisNp iteration 0
# INFO:drake:IrisNp iteration 1
# INFO:drake:IrisNp iteration 2
# INFO:drake: Checking iiwa::Mesh against shelves::top has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking iiwa::Mesh against shelves::top after 75 counter-example searches.
# INFO:drake:IrisNp: terminating iterations because the seed point is no longer in the region.
# 'Finished seed Above Shelve; Computation time: 15.33 seconds'
# 'Computing region for seed: Top Rack'
# INFO:drake:IrisNp iteration 0
# INFO:drake:IrisNp iteration 1
# INFO:drake:IrisNp iteration 2
# INFO:drake:IrisNp iteration 3
# INFO:drake:IrisNp iteration 4
# INFO:drake: Checking wsg::collision against shelves::top has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking wsg::collision against shelves::top after 39 counter-example searches.
# INFO:drake:IrisNp iteration 5
# INFO:drake: Checking wsg::collision against shelves::top has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking wsg::collision against shelves::top after 54 counter-example searches.
# INFO:drake:IrisNp iteration 6
# INFO:drake: Checking iiwa::Mesh against shelves::top has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking iiwa::Mesh against shelves::top after 30 counter-example searches.
# INFO:drake: Checking wsg::collision against shelves::top has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking wsg::collision against shelves::top after 50 counter-example searches.
# INFO:drake:IrisNp iteration 7
# INFO:drake: Checking wsg::collision against shelves::top has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking wsg::collision against shelves::top after 49 counter-example searches.
# INFO:drake:IrisNp iteration 8
# INFO:drake: Checking wsg::collision against shelves::top has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking wsg::collision against shelves::top after 45 counter-example searches.
# INFO:drake:IrisNp iteration 9
# INFO:drake: Checking wsg::collision against shelves::top has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking wsg::collision against shelves::top after 39 counter-example searches.
# INFO:drake:IrisNp: Terminating because the iteration limit 10 has been reached.
# 'Finished seed Top Rack; Computation time: 59.63 seconds'
# 'Computing region for seed: Middle Rack'
# INFO:drake:IrisNp iteration 0
# INFO:drake:IrisNp iteration 1
# INFO:drake:IrisNp iteration 2
# INFO:drake:IrisNp iteration 3
# INFO:drake:IrisNp iteration 4
# INFO:drake:IrisNp iteration 5
# INFO:drake: Checking wsg::collision against shelves::shelf_upper has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking wsg::collision against shelves::shelf_upper after 32 counter-example searches.
# INFO:drake:IrisNp iteration 6
# INFO:drake: Checking wsg::collision against shelves::shelf_upper has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking wsg::collision against shelves::shelf_upper after 39 counter-example searches.
# INFO:drake:IrisNp iteration 7
# INFO:drake: Checking wsg::collision against shelves::shelf_upper has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking wsg::collision against shelves::shelf_upper after 32 counter-example searches.
# INFO:drake:IrisNp iteration 8
# INFO:drake: Checking wsg::collision against shelves::shelf_upper has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking wsg::collision against shelves::shelf_upper after 30 counter-example searches.
# INFO:drake:IrisNp: Terminating because the hyperellipsoid relative volume change 0.008000886966505413 is below the threshold 0.01.
# 'Finished seed Middle Rack; Computation time: 40.36 seconds'
# 'Computing region for seed: Left Bin'
# INFO:drake:IrisNp iteration 0
# INFO:drake:IrisNp iteration 1
# INFO:drake:IrisNp iteration 2
# INFO:drake:IrisNp iteration 3
# INFO:drake:IrisNp iteration 4
# INFO:drake:IrisNp: terminating iterations because the seed point is no longer in the region.
# 'Finished seed Left Bin; Computation time: 23.51 seconds'
# 'Computing region for seed: Right Bin'
# INFO:drake:IrisNp iteration 0
# INFO:drake:IrisNp iteration 1
# INFO:drake:IrisNp iteration 2
# INFO:drake:IrisNp iteration 3
# INFO:drake: Checking wsg::collision against binR::front has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking wsg::collision against binR::front after 31 counter-example searches.
# INFO:drake:IrisNp iteration 4
# INFO:drake: Checking wsg::collision against binR::front has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking wsg::collision against binR::front after 35 counter-example searches.
# INFO:drake:IrisNp: terminating iterations because the seed point is no longer in the region.
# 'Finished seed Right Bin; Computation time: 22.36 seconds'
# 'Computing region for seed: Front to Shelve'
# INFO:drake:IrisNp iteration 0
# INFO:drake:IrisNp iteration 1
# INFO:drake:IrisNp iteration 2
# INFO:drake:IrisNp iteration 3
# INFO:drake:IrisNp iteration 4
# INFO:drake:IrisNp iteration 5
# INFO:drake:IrisNp: terminating iterations because the seed point is no longer in the region.
# 'Finished seed Front to Shelve; Computation time: 31.00 seconds'
# 'Computing region for seed: Left to Shelve'
# INFO:drake:IrisNp iteration 0
# INFO:drake:IrisNp iteration 1
# INFO:drake:IrisNp iteration 2
# INFO:drake:IrisNp iteration 3
# INFO:drake:IrisNp iteration 4
# INFO:drake:IrisNp: terminating iterations because the seed point is no longer in the region.
# 'Finished seed Left to Shelve; Computation time: 24.25 seconds'
# 'Computing region for seed: Right to Shelve'
# INFO:drake:IrisNp iteration 0
# INFO:drake:IrisNp iteration 1
# INFO:drake:IrisNp iteration 2
# INFO:drake: Checking wsg::collision against shelves::left_wall has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking wsg::collision against shelves::left_wall after 33 counter-example searches.
# INFO:drake:IrisNp iteration 3
# INFO:drake: Checking wsg::collision against shelves::left_wall has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking wsg::collision against shelves::left_wall after 46 counter-example searches.
# INFO:drake:IrisNp iteration 4
# INFO:drake:IrisNp: terminating iterations because the seed point is no longer in the region.
# 'Finished seed Right to Shelve; Computation time: 31.29 seconds'

# %%
VisualizeRegion("Top Rack")
VisualizeRegions()
# Out:
# Press Enter to visualize the next region
# Press Enter to visualize the next region
# Press Enter to visualize the next region
# Press Enter to visualize the next region
# Press Enter to visualize the next region
# Press Enter to visualize the next region
# Press Enter to visualize the next region
# Press Enter to visualize the next region
# Press Enter to visualize the next region

# %% [markdown]
# ## End-effector Teleop

# %%
from collections import namedtuple
from copy import copy

from pydrake.all import Context, Meshcat, MeshcatPoseSliders, SceneGraph

RpyXyz = namedtuple("RpyXyz", ("roll", "pitch", "yaw", "x", "y", "z"))


# Creates an indicator "light" (a colored sphere in the workspace)
# TODO(russt): use meshcat.SetProperty(path, "color", rgba) instead
def IrisIndicator(
    scene_graph: SceneGraph,
    scene_graph_context: Context,
    meshcat: Meshcat,
    iris_regions: Dict[str, HPolyhedron],
    p_WIndicator: list,
):
    radius = 0.1

    meshcat.SetTransform("iris_indicator", RigidTransform(p_WIndicator))

    query_object = scene_graph.get_query_output_port().Eval(scene_graph_context)
    has_collisions = query_object.HasCollisions()
    if has_collisions:
        meshcat.SetObject("iris_indicator", Sphere(radius), Rgba(1, 0, 0, 1))

    in_any_region = False
    for r in iris_regions.values():
        if r.PointInSet(q):
            if has_collisions:
                print("You found a counter-example!")
                # TODO(russt): Automatically shrink the iris region.
            elif not in_any_region:
                in_any_region = True
                meshcat.SetObject("iris_indicator", Sphere(radius), Rgba(0, 1, 0, 1))

    if not has_collisions and not in_any_region:
        meshcat.SetObject("iris_indicator", Sphere(radius), Rgba(0.5, 0.5, 0.5, 1))


def EndEffectorTeleop():
    meshcat.Delete()
    meshcat.DeleteAddedControls()

    builder = DiagramBuilder()
    plant, scene_graph = AddMultibodyPlantSceneGraph(builder, 0.0)
    ee_body = LoadRobot(plant)
    plant.Finalize()

    # Set up teleop widgets.
    sliders = builder.AddSystem(
        MeshcatPoseSliders(
            meshcat,
            lower_limit=RpyXyz(roll=0, pitch=-0.5, yaw=-np.pi, x=-0.6, y=-0.8, z=0.0),
            upper_limit=RpyXyz(
                roll=2 * np.pi, pitch=np.pi, yaw=np.pi, x=0.8, y=0.3, z=1.1
            ),
        )
    )
    print(
        """
Control the end-effector position/orientation with the sliders or the keyboard:
  ┌───────┬┬───────┬┬───────┐      ┌───────┬┬───────┬┬───────┐
  │   Q   ││   W   ││   E   │      │   U   ││   I   ││   O   │
  │ roll- ││ pitch+││ roll+ │      │   z-  ││   y+  ││   z+  │
  ├───────┼┼───────┼┼───────┤      ├───────┼┼───────┼┼───────┤
  ├───────┼┼───────┼┼───────┤      ├───────┼┼───────┼┼───────┤
  │   A   ││   S   ││   D   │      │   J   ││   K   ││   L   │
  │  yaw- ││ pitch-││  yaw+ │      │   x-  ││   y-  ││   x+  │
  └───────┴┴───────┴┴───────┘      └───────┴┴───────┴┴───────┘
"""
    )

    AddDefaultVisualization(builder, meshcat)

    diagram = builder.Build()
    context = diagram.CreateDefaultContext()
    plant_context = plant.GetMyMutableContextFromRoot(context)
    scene_graph_context = scene_graph.GetMyContextFromRoot(context)
    sliders_context = sliders.GetMyContextFromRoot(context)

    global q
    if len(q) == 0:
        q = plant.GetPositions(plant_context)
    plant.SetPositions(plant_context, q)
    X_WE = plant.EvalBodyPoseInWorld(plant_context, ee_body)
    sliders.SetPose(X_WE)

    iris_button_name = "Compute new IRIS region"
    meshcat.AddButton(iris_button_name)
    iris_button_clicks = 0

    stop_button_name = "Stop End Effector Teleop"
    print(
        f"Press the '{stop_button_name}' button in Meshcat to continue or press 'Escape'"
    )
    meshcat.AddButton(stop_button_name, "Escape")

    diagram.ForcedPublish(context)
    if not running_as_notebook:
        return

    while meshcat.GetButtonClicks(stop_button_name) < 1:
        # Check if the sliders have changed.
        new_X_WE = copy(sliders.get_output_port().Eval(sliders_context))

        if meshcat.GetButtonClicks(iris_button_name) > iris_button_clicks:
            iris_button_clicks = meshcat.GetButtonClicks(iris_button_name)
            # TODO(russt): Get the name from meshcat (#19666)
            region_name = "EETeleopRegion"
            region_num = 0
            while f"{region_name}{region_num}" in iris_regions.keys():
                region_num += 1
            meshcat.AddButton("Generating region (please wait)")
            GenerateRegion(
                f"{region_name}{region_num}", plant.GetPositions(plant_context)
            )
            meshcat.DeleteButton("Generating region (please wait)")
        elif X_WE.IsExactlyEqualTo(new_X_WE):
            time.sleep(1e-3)
            continue

        X_WE = new_X_WE
        q_ik = MyInverseKinematics(X_WE, plant, plant_context)
        if q_ik is not None:
            q = q_ik
            plant.SetPositions(plant_context, q)
            IrisIndicator(
                scene_graph,
                scene_graph_context,
                meshcat,
                iris_regions,
                p_WIndicator=[1, 1, 1],
            )
            diagram.ForcedPublish(context)

    meshcat.DeleteAddedControls()
    q = plant.GetPositions(plant_context)


EndEffectorTeleop()
# Out:
# Control the end-effector position/orientation with the sliders or the keyboard:
#   ┌───────┬┬───────┬┬───────┐      ┌───────┬┬───────┬┬───────┐
#   │   Q   ││   W   ││   E   │      │   U   ││   I   ││   O   │
#   │ roll- ││ pitch+││ roll+ │      │   z-  ││   y+  ││   z+  │
#   ├───────┼┼───────┼┼───────┤      ├───────┼┼───────┼┼───────┤
#   ├───────┼┼───────┼┼───────┤      ├───────┼┼───────┼┼───────┤
#   │   A   ││   S   ││   D   │      │   J   ││   K   ││   L   │
#   │  yaw- ││ pitch-││  yaw+ │      │   x-  ││   y-  ││   x+  │
#   └───────┴┴───────┴┴───────┘      └───────┴┴───────┴┴───────┘
#
# Press the 'Stop End Effector Teleop' button in Meshcat to continue or press 'Escape'
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# IK failed
# 'Computing region for seed: EETeleopRegion0'
# /var/folders/k4/mg5n76b53w31r9_hw85j51xh0000gn/T/ipykernel_24194/1304875030.py:42: DrakeDeprecationWarning: (Deprecated.)
#
# Deprecated:
#     Use IrisNp instead. This will be removed from Drake on or after
#     2025-12-01.
#   hpoly = IrisInConfigurationSpace(plant, plant_context, iris_options)
# INFO:drake:IrisNp iteration 0
# INFO:drake:IrisNp iteration 1
# INFO:drake:IrisNp iteration 2
# INFO:drake:IrisNp: terminating iterations because the seed point is no longer in the region.
# 'Finished seed EETeleopRegion0; Computation time: 8.48 seconds'
# IK failed

# %% [markdown]
# ### Sometimes it's useful to reset the teleop to the default (home) position

# %%
q = get_default_position()

# %% [markdown]
# ## Joint Teleop

# %%
def JointTeleop():
    meshcat.Delete()
    meshcat.DeleteAddedControls()
    builder = DiagramBuilder()

    plant, scene_graph = AddMultibodyPlantSceneGraph(builder, time_step=0.0)
    LoadRobot(plant)
    plant.Finalize()

    sliders = builder.AddSystem(JointSliders(meshcat, plant))

    AddDefaultVisualization(builder, meshcat)
    diagram = builder.Build()
    context = diagram.CreateDefaultContext()
    plant_context = plant.GetMyMutableContextFromRoot(context)
    scene_graph_context = scene_graph.GetMyContextFromRoot(context)
    sliders_context = sliders.GetMyContextFromRoot(context)

    global q
    if len(q) == 0:
        q = plant.GetPositions(plant_context)
    sliders.SetPositions(q)

    # Implements a version of JointSliders.run() which can also watch for extra UI events.
    iris_button_name = "Compute new IRIS region"
    meshcat.AddButton(iris_button_name)
    iris_button_clicks = 0

    stop_button_name = "Stop Joint Teleop"
    print(
        f"Press the '{stop_button_name}' button in Meshcat to continue or press 'Escape'"
    )
    meshcat.AddButton(stop_button_name, "Escape")

    diagram.ForcedPublish(context)
    if not running_as_notebook:
        return

    while meshcat.GetButtonClicks(stop_button_name) < 1:
        # Check if the sliders have changed.
        old_positions = plant.GetPositions(plant_context)
        new_positions = sliders.get_output_port().Eval(sliders_context)

        if meshcat.GetButtonClicks(iris_button_name) > iris_button_clicks:
            iris_button_clicks = meshcat.GetButtonClicks(iris_button_name)
            # TODO(russt): Get the name from meshcat (#19666)
            region_name = "JointTeleopRegion"
            region_num = 0
            while f"{region_name}{region_num}" in iris_regions.keys():
                region_num += 1
            meshcat.AddButton("Generating region (please wait)")
            GenerateRegion(f"{region_name}{region_num}", new_positions)
            meshcat.DeleteButton("Generating region (please wait)")
        elif np.array_equal(new_positions, old_positions):
            time.sleep(1e-3)
            continue

        # Publish the new positions.
        plant.SetPositions(plant_context, new_positions)
        IrisIndicator(
            scene_graph,
            scene_graph_context,
            meshcat,
            iris_regions,
            p_WIndicator=[1, 1, 1],
        )
        diagram.ForcedPublish(context)

    meshcat.DeleteAddedControls()


JointTeleop()
# Out:
# Press the 'Stop Joint Teleop' button in Meshcat to continue or press 'Escape'

# %% [markdown]
# ## Random sampling
#
# Simple rejection sampling can work, but we have some much nicer methods coming soon.

# %% [markdown]
# # Introspection
#
# ## Visualize the current IRIS region connectivity
#
# For planning trajectories, it's important to have some non-empty intersection between the convex sets. Here is a simple utility the visualization the connectivity as a graph.

# %%
def VisualizeConnectivity():
    graph = pydot.Dot("IRIS region connectivity")
    keys = list(iris_regions.keys())
    for k in keys:
        graph.add_node(pydot.Node(k))
    for i in range(len(keys)):
        v1 = iris_regions[keys[i]]
        for j in range(i + 1, len(keys)):
            v2 = iris_regions[keys[j]]
            if v1.IntersectsWith(v2):
                graph.add_edge(pydot.Edge(keys[i], keys[j], dir="both"))
    display(SVG(graph.create_svg()))


VisualizeConnectivity()

# %% [markdown]
# ## Visualize a region

# %%
if running_as_notebook and iris_regions:
    VisualizeRegions()
# Out:
# Press Enter to visualize the next region
# Press Enter to visualize the next region
# Press Enter to visualize the next region
# Press Enter to visualize the next region
# Press Enter to visualize the next region
# Press Enter to visualize the next region
# Press Enter to visualize the next region
# Press Enter to visualize the next region
# Press Enter to visualize the next region
# Press Enter to visualize the next region

# %% [markdown]
# ## Plan trajectories with GCS Trajectory Optimization

# %%
from pydrake.geometry.optimization import GraphOfConvexSetsOptions, Point
from pydrake.planning import GcsTrajectoryOptimization


def PublishPositionTrajectory(
    trajectory, root_context, plant, visualizer, time_step=1.0 / 33.0
):
    """
    Args:
        trajectory: A Trajectory instance.
    """
    plant_context = plant.GetMyContextFromRoot(root_context)
    visualizer_context = visualizer.GetMyContextFromRoot(root_context)

    visualizer.StartRecording(False)

    for t in np.append(
        np.arange(trajectory.start_time(), trajectory.end_time(), time_step),
        trajectory.end_time(),
    ):
        root_context.SetTime(t)
        plant.SetPositions(plant_context, trajectory.value(t))
        visualizer.ForcedPublish(visualizer_context)

    visualizer.StopRecording()
    visualizer.PublishRecording()


def GcsTrajOpt(q_start, q_goal):
    if not iris_regions:
        print(
            "No IRIS regions loaded. Make some IRIS regions then come back and try this again."
        )
        return
    assert len(q_start) == len(q_goal)
    assert len(q_start) == iris_regions[next(iter(iris_regions))].ambient_dimension()

    builder = DiagramBuilder()
    plant, scene_graph = AddMultibodyPlantSceneGraph(builder, time_step=0.0)
    LoadRobot(plant)
    plant.Finalize()
    AddDefaultVisualization(builder, meshcat)
    diagram = builder.Build()

    gcs = GcsTrajectoryOptimization(len(q_start))
    # TODO(russt): AddRegions should take named regions.
    regions = gcs.AddRegions(list(iris_regions.values()), order=1)
    source = gcs.AddRegions([Point(q_start)], order=0)
    target = gcs.AddRegions([Point(q_goal)], order=0)
    gcs.AddEdges(source, regions)
    gcs.AddEdges(regions, target)
    gcs.AddTimeCost()
    gcs.AddVelocityBounds(
        plant.GetVelocityLowerLimits(), plant.GetVelocityUpperLimits()
    )

    options = GraphOfConvexSetsOptions()
    options.preprocessing = True
    options.max_rounded_paths = 5
    start_time = time.time()
    traj, result = gcs.SolvePath(source, target, options)
    print(f"GCS solved in {time.time() - start_time} seconds")
    if not result.is_success():
        print("Could not find a feasible path from q_start to q_goal")
        return

    PublishPositionTrajectory(
        traj,
        diagram.CreateDefaultContext(),
        plant,
        diagram.GetSubsystemByName("meshcat_visualizer(illustration)"),
    )

# %%
assert (
    seeds
), "The examples here use the 'manually-specified seeds' from the section above. Please run that section first, or populate your own start and end configurations."

GcsTrajOpt(seeds["Home Position"], seeds["Top Rack"])
# Out:
# INFO:drake:Solved GCS shortest path using Clp with convex_relaxation=true and preprocessing=true and rounding.
# INFO:drake:Found 5 unique paths, discarded 5 duplicate paths.
# INFO:drake:Finished 5 rounding solutions with Clp.
# GCS solved in 8.013919115066528 seconds

# %%
for k in range(4 if running_as_notebook else 0):
    GcsTrajOpt(seeds["Top Rack"], seeds["Left Bin"])
    GcsTrajOpt(seeds["Left Bin"], seeds["Middle Rack"])
    GcsTrajOpt(seeds["Middle Rack"], seeds["Right Bin"])
    GcsTrajOpt(seeds["Right Bin"], seeds["Top Rack"])
# Out:
# INFO:drake:Solved GCS shortest path using Clp with convex_relaxation=true and preprocessing=true and rounding.
# INFO:drake:Found 5 unique paths, discarded 5 duplicate paths.
# INFO:drake:Finished 5 rounding solutions with Clp.
# GCS solved in 8.481303930282593 seconds
# INFO:drake:Solved GCS shortest path using Clp with convex_relaxation=true and preprocessing=true and rounding.
# INFO:drake:Found 4 unique paths, discarded 96 duplicate paths.
# INFO:drake:Finished 4 rounding solutions with Clp.
# GCS solved in 16.715688943862915 seconds
# INFO:drake:Solved GCS shortest path using Clp with convex_relaxation=true and preprocessing=true and rounding.
# INFO:drake:Found 5 unique paths, discarded 17 duplicate paths.
# INFO:drake:Finished 5 rounding solutions with Clp.
# GCS solved in 12.378392934799194 seconds
# INFO:drake:Solved GCS shortest path using Clp with convex_relaxation=true and preprocessing=true and rounding.
# INFO:drake:Found 5 unique paths, discarded 22 duplicate paths.
# INFO:drake:Finished 5 rounding solutions with Clp.
# GCS solved in 9.924532175064087 seconds
# INFO:drake:Solved GCS shortest path using Clp with convex_relaxation=true and preprocessing=true and rounding.
# INFO:drake:Found 5 unique paths, discarded 5 duplicate paths.
# INFO:drake:Finished 5 rounding solutions with Clp.
# GCS solved in 7.925693988800049 seconds
# INFO:drake:Solved GCS shortest path using Clp with convex_relaxation=true and preprocessing=true and rounding.
# INFO:drake:Found 4 unique paths, discarded 96 duplicate paths.
# INFO:drake:Finished 4 rounding solutions with Clp.
# GCS solved in 16.69304394721985 seconds
# INFO:drake:Solved GCS shortest path using Clp with convex_relaxation=true and preprocessing=true and rounding.
# INFO:drake:Found 5 unique paths, discarded 17 duplicate paths.
# INFO:drake:Finished 5 rounding solutions with Clp.
# GCS solved in 12.655449867248535 seconds
# INFO:drake:Solved GCS shortest path using Clp with convex_relaxation=true and preprocessing=true and rounding.
# INFO:drake:Found 5 unique paths, discarded 22 duplicate paths.
# INFO:drake:Finished 5 rounding solutions with Clp.
# GCS solved in 10.103693008422852 seconds
# INFO:drake:Solved GCS shortest path using Clp with convex_relaxation=true and preprocessing=true and rounding.
# INFO:drake:Found 5 unique paths, discarded 5 duplicate paths.
# INFO:drake:Finished 5 rounding solutions with Clp.
# GCS solved in 7.6673970222473145 seconds
# INFO:drake:Solved GCS shortest path using Clp with convex_relaxation=true and preprocessing=true and rounding.
# INFO:drake:Found 4 unique paths, discarded 96 duplicate paths.
# INFO:drake:Finished 4 rounding solutions with Clp.
# GCS solved in 16.539910793304443 seconds
# INFO:drake:Solved GCS shortest path using Clp with convex_relaxation=true and preprocessing=true and rounding.
# INFO:drake:Found 5 unique paths, discarded 17 duplicate paths.
# INFO:drake:Finished 5 rounding solutions with Clp.
# GCS solved in 12.898869037628174 seconds
# INFO:drake:Solved GCS shortest path using Clp with convex_relaxation=true and preprocessing=true and rounding.
# INFO:drake:Found 5 unique paths, discarded 22 duplicate paths.
# INFO:drake:Finished 5 rounding solutions with Clp.
# GCS solved in 9.820307970046997 seconds
# INFO:drake:Solved GCS shortest path using Clp with convex_relaxation=true and preprocessing=true and rounding.
# INFO:drake:Found 5 unique paths, discarded 5 duplicate paths.
# INFO:drake:Finished 5 rounding solutions with Clp.
# GCS solved in 7.6902289390563965 seconds
# INFO:drake:Solved GCS shortest path using Clp with convex_relaxation=true and preprocessing=true and rounding.
# INFO:drake:Found 4 unique paths, discarded 96 duplicate paths.
# INFO:drake:Finished 4 rounding solutions with Clp.
# GCS solved in 16.56440806388855 seconds
# INFO:drake:Solved GCS shortest path using Clp with convex_relaxation=true and preprocessing=true and rounding.
# INFO:drake:Found 5 unique paths, discarded 17 duplicate paths.
# INFO:drake:Finished 5 rounding solutions with Clp.
# GCS solved in 12.661661148071289 seconds
# INFO:drake:Solved GCS shortest path using Clp with convex_relaxation=true and preprocessing=true and rounding.
# INFO:drake:Found 5 unique paths, discarded 22 duplicate paths.
# INFO:drake:Finished 5 rounding solutions with Clp.
# GCS solved in 9.961736917495728 seconds

# %% [markdown]
# # Save your regions back to disk
#
# Note that by default, this notebook will autosave a backup after making each region.

# %%
if running_as_notebook:
    SaveIrisRegionsYamlFile(iris_filename, iris_regions)

# %% [markdown]
# # Clean up
#
# For good measure, let's delete any temporary license files now.

# %%
if os.path.exists("/tmp/mosek.lic"):
    os.remove("/tmp/mosek.lic")
